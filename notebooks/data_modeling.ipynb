# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import xgboost as xgb

# %% [markdown]
# ### Read Preporcessed data

# %%
dataset = pd.read_csv('../data/processed/pre_processed_dataset.csv', encoding="iso-8859-1")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   target           1600000 non-null  int64
#  1   ids              1600000 non-null  int64
#  2   date             1600000 non-null  object
#  3   flag             1600000 non-null  object
#  4   user             1600000 non-null  object
#  5   text             1600000 non-null  object
#  6   stemmed_content  1599505 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 85.4+ MB

# %%
df = dataset['stemmed_content']

# %%
df.loc[df.isnull()] = ''
# Out:
# C:\Users\niraj\AppData\Local\Temp\ipykernel_19332\1563410368.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df.isnull()] = ''

# %%
dataset['stemmed_content'] = df

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   target           1600000 non-null  int64
#  1   ids              1600000 non-null  int64
#  2   date             1600000 non-null  object
#  3   flag             1600000 non-null  object
#  4   user             1600000 non-null  object
#  5   text             1600000 non-null  object
#  6   stemmed_content  1600000 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 85.4+ MB

# %%
dataset.head()
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text  \
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - awww, t...
# 1    scotthamilton  is upset that he can't update his facebook by ...
# 2         mattycus  @kenichan i dived many times for the ball. man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....
#
#                                      stemmed_content
# 0  switchfoot http twitpic com zl awww bummer sho...
# 1  upset updat facebook text might cri result sch...
# 2  kenichan dive mani time ball manag save rest g...
# 3                    whole bodi feel itchi like fire
# 4                      nationwideclass behav mad see

# %% [markdown]
# ### split the data to 20% for train && 80% for train

# %%
X = dataset['stemmed_content']
Y = dataset['target']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)

# %% [markdown]
# ### Vectorization, Fit and transform Data

# %%
vectorize = TfidfVectorizer()

# %%
X_train = vectorize.fit_transform(X_train)

# %%
X_test = vectorize.transform(X_test)

# %%
print(X_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 9453607 stored elements and shape (1280000, 461280)>
#   Coords	Values
#   (0, 307108)	0.46206048815324474
#   (0, 239679)	0.15130037108228483
#   (0, 146067)	0.12929728405657018
#   (0, 175252)	0.224070805470346
#   (0, 128605)	0.22108856600702773
#   (0, 4832)	0.317074267861159
#   (0, 124524)	0.18318401951949756
#   (0, 205794)	0.24140229063801746
#   (0, 454381)	0.20169626473577715
#   (0, 286478)	0.16123218610004272
#   (0, 406297)	0.2978221095272138
#   (0, 220296)	0.43015677907624866
#   (0, 388138)	0.20555120011808467
#   (0, 154767)	0.26976607043258233
#   (1, 445870)	0.6361096685891185
#   (1, 161801)	0.5778049407933611
#   (1, 124611)	0.5113765148324884
#   (2, 125319)	0.6383069130836649
#   (2, 349409)	0.22232944888223494
#   (2, 444761)	0.30331529032956345
#   (2, 358186)	0.19837942712286838
#   (2, 267649)	0.19309660201644555
#   (2, 12436)	0.2529872032123258
#   (2, 453420)	0.2347069337186747
#   (2, 312657)	0.3154702974657607
#   :	:
#   (1279997, 124611)	0.2537781914144255
#   (1279997, 301683)	0.1908678391932645
#   (1279997, 168646)	0.20490659397970187
#   (1279997, 156392)	0.23570311036994007
#   (1279997, 151848)	0.18681351768822982
#   (1279997, 259065)	0.26819595864353835
#   (1279997, 394120)	0.24857410036759808
#   (1279997, 372797)	0.3021907911926725
#   (1279997, 262076)	0.3257051331036561
#   (1279997, 80839)	0.4085075096529922
#   (1279997, 120136)	0.5183864288132355
#   (1279998, 329551)	0.3477852392627569
#   (1279998, 71116)	0.26101247237184594
#   (1279998, 49119)	0.24937088067546037
#   (1279998, 115954)	0.24199212168201903
#   (1279998, 442745)	0.46003281711454636
#   (1279998, 138188)	0.22903437381896502
#   (1279998, 33019)	0.5505296949726769
#   (1279998, 225235)	0.3507164257239226
#   (1279999, 169469)	0.24275491614294809
#   (1279999, 104826)	0.39497658307784106
#   (1279999, 388491)	0.3269499490733422
#   (1279999, 118242)	0.3604832171863622
#   (1279999, 349900)	0.3245817059299737
#   (1279999, 267426)	0.6654816651208961

# %% [markdown]
# ### Model Building

# %%
model = xgb.XGBClassifier(tree_method = 'hist', early_stopping_rounds = 2)

# %%
model.fit(X_train, Y_train, eval_set=[(X_train, Y_train)])
# Out:
# [0]	validation_0-logloss:0.67353
# [1]	validation_0-logloss:0.66136
# [2]	validation_0-logloss:0.65231
# [3]	validation_0-logloss:0.64486
# [4]	validation_0-logloss:0.63830
# [5]	validation_0-logloss:0.63318
# [6]	validation_0-logloss:0.62835
# [7]	validation_0-logloss:0.62378
# [8]	validation_0-logloss:0.62001
# [9]	validation_0-logloss:0.61635
# [10]	validation_0-logloss:0.61318
# [11]	validation_0-logloss:0.61036
# [12]	validation_0-logloss:0.60771
# [13]	validation_0-logloss:0.60462
# [14]	validation_0-logloss:0.60212
# [15]	validation_0-logloss:0.59983
# [16]	validation_0-logloss:0.59764
# [17]	validation_0-logloss:0.59529
# [18]	validation_0-logloss:0.59334
# [19]	validation_0-logloss:0.59151
# [20]	validation_0-logloss:0.58929
# [21]	validation_0-logloss:0.58743
# [22]	validation_0-logloss:0.58576
# [23]	validation_0-logloss:0.58406
# [24]	validation_0-logloss:0.58251
# [25]	validation_0-logloss:0.58104
# [26]	validation_0-logloss:0.57963
# [27]	validation_0-logloss:0.57825
# [28]	validation_0-logloss:0.57689
# [29]	validation_0-logloss:0.57549
# [30]	validation_0-logloss:0.57419
# [31]	validation_0-logloss:0.57262
# [32]	validation_0-logloss:0.57140
# [33]	validation_0-logloss:0.57025
# [34]	validation_0-logloss:0.56914
# [35]	validation_0-logloss:0.56809
# [36]	validation_0-logloss:0.56707
# [37]	validation_0-logloss:0.56611
# [38]	validation_0-logloss:0.56494
# [39]	validation_0-logloss:0.56396
# [40]	validation_0-logloss:0.56291
# [41]	validation_0-logloss:0.56198
# [42]	validation_0-logloss:0.56111
# [43]	validation_0-logloss:0.56022
# [44]	validation_0-logloss:0.55936
# [45]	validation_0-logloss:0.55834
# [46]	validation_0-logloss:0.55751
# [47]	validation_0-logloss:0.55668
# [48]	validation_0-logloss:0.55589
# [49]	validation_0-logloss:0.55506
# [50]	validation_0-logloss:0.55425
# [51]	validation_0-logloss:0.55347
# [52]	validation_0-logloss:0.55274
# [53]	validation_0-logloss:0.55200
# [54]	validation_0-logloss:0.55129
# [55]	validation_0-logloss:0.55057
# [56]	validation_0-logloss:0.54988
# [57]	validation_0-logloss:0.54914
# [58]	validation_0-logloss:0.54850
# [59]	validation_0-logloss:0.54774
# [60]	validation_0-logloss:0.54708
# [61]	validation_0-logloss:0.54648
# [62]	validation_0-logloss:0.54572
# [63]	validation_0-logloss:0.54512
# [64]	validation_0-logloss:0.54443
# [65]	validation_0-logloss:0.54381
# [66]	validation_0-logloss:0.54320
# [67]	validation_0-logloss:0.54265
# [68]	validation_0-logloss:0.54212
# [69]	validation_0-logloss:0.54160
# [70]	validation_0-logloss:0.54106
# [71]	validation_0-logloss:0.54056
# [72]	validation_0-logloss:0.54008
# [73]	validation_0-logloss:0.53953
# [74]	validation_0-logloss:0.53897
# [75]	validation_0-logloss:0.53850
# [76]	validation_0-logloss:0.53801
# [77]	validation_0-logloss:0.53747
# [78]	validation_0-logloss:0.53703
# [79]	validation_0-logloss:0.53659
# [80]	validation_0-logloss:0.53613
# [81]	validation_0-logloss:0.53565
# [82]	validation_0-logloss:0.53524
# [83]	validation_0-logloss:0.53483
# [84]	validation_0-logloss:0.53440
# [85]	validation_0-logloss:0.53391
# [86]	validation_0-logloss:0.53337
# [87]	validation_0-logloss:0.53288
# [88]	validation_0-logloss:0.53245
# [89]	validation_0-logloss:0.53203
# [90]	validation_0-logloss:0.53163
# [91]	validation_0-logloss:0.53121
# [92]	validation_0-logloss:0.53083
# [93]	validation_0-logloss:0.53045
# [94]	validation_0-logloss:0.53007
# [95]	validation_0-logloss:0.52969
# [96]	validation_0-logloss:0.52915
# [97]	validation_0-logloss:0.52877
# [98]	validation_0-logloss:0.52838
# [99]	validation_0-logloss:0.52799
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=2,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### Model Evaluation

# %%
train_score = model.score(X_train, Y_train)
test_score = model.score(X_test, Y_test)

# %%
print(train_score)
# Out:
# 0.7447078125

# %%
print(test_score)
# Out:
# 0.74119375

# %%
y_pred = model.predict(X_test[-2])

# %%
print(y_pred)
# Out:
# [0]

# %%
Y_test
# Out:
# 291262     0
# 1359075    1
# 1009651    1
# 1538714    1
# 1046690    1
#           ..
# 203556     0
# 163122     0
# 1176116    1
# 477177     0
# 897066     1
# Name: target, Length: 320000, dtype: int64

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
model2 = xgb.XGBClassifier(tree_method = 'hist', eta = 0.9, early_stopping_rounds = 2, gamma = 4, objective="binary:logistic", max_depth = 8, subsample = 0.6)

# %%
model2.fit(X_train, Y_train, eval_set=[(X_train, Y_train)])
# Out:
# [0]	validation_0-logloss:0.64525
# [1]	validation_0-logloss:0.62310
# [2]	validation_0-logloss:0.60913
# [3]	validation_0-logloss:0.59878
# [4]	validation_0-logloss:0.59057
# [5]	validation_0-logloss:0.58283
# [6]	validation_0-logloss:0.57715
# [7]	validation_0-logloss:0.57192
# [8]	validation_0-logloss:0.56735
# [9]	validation_0-logloss:0.56260
# [10]	validation_0-logloss:0.55876
# [11]	validation_0-logloss:0.55455
# [12]	validation_0-logloss:0.55133
# [13]	validation_0-logloss:0.54835
# [14]	validation_0-logloss:0.54551
# [15]	validation_0-logloss:0.54271
# [16]	validation_0-logloss:0.54046
# [17]	validation_0-logloss:0.53831
# [18]	validation_0-logloss:0.53625
# [19]	validation_0-logloss:0.53424
# [20]	validation_0-logloss:0.53225
# [21]	validation_0-logloss:0.53057
# [22]	validation_0-logloss:0.52875
# [23]	validation_0-logloss:0.52697
# [24]	validation_0-logloss:0.52559
# [25]	validation_0-logloss:0.52418
# [26]	validation_0-logloss:0.52293
# [27]	validation_0-logloss:0.52172
# [28]	validation_0-logloss:0.52033
# [29]	validation_0-logloss:0.51887
# [30]	validation_0-logloss:0.51777
# [31]	validation_0-logloss:0.51654
# [32]	validation_0-logloss:0.51555
# [33]	validation_0-logloss:0.51455
# [34]	validation_0-logloss:0.51363
# [35]	validation_0-logloss:0.51271
# [36]	validation_0-logloss:0.51180
# [37]	validation_0-logloss:0.51091
# [38]	validation_0-logloss:0.51011
# [39]	validation_0-logloss:0.50924
# [40]	validation_0-logloss:0.50846
# [41]	validation_0-logloss:0.50773
# [42]	validation_0-logloss:0.50701
# [43]	validation_0-logloss:0.50628
# [44]	validation_0-logloss:0.50538
# [45]	validation_0-logloss:0.50472
# [46]	validation_0-logloss:0.50406
# [47]	validation_0-logloss:0.50341
# [48]	validation_0-logloss:0.50269
# [49]	validation_0-logloss:0.50203
# [50]	validation_0-logloss:0.50136
# [51]	validation_0-logloss:0.50067
# [52]	validation_0-logloss:0.50013
# [53]	validation_0-logloss:0.49956
# [54]	validation_0-logloss:0.49901
# [55]	validation_0-logloss:0.49849
# [56]	validation_0-logloss:0.49796
# [57]	validation_0-logloss:0.49747
# [58]	validation_0-logloss:0.49697
# [59]	validation_0-logloss:0.49647
# [60]	validation_0-logloss:0.49590
# [61]	validation_0-logloss:0.49528
# [62]	validation_0-logloss:0.49484
# [63]	validation_0-logloss:0.49438
# [64]	validation_0-logloss:0.49390
# [65]	validation_0-logloss:0.49344
# [66]	validation_0-logloss:0.49299
# [67]	validation_0-logloss:0.49259
# [68]	validation_0-logloss:0.49204
# [69]	validation_0-logloss:0.49161
# [70]	validation_0-logloss:0.49120
# [71]	validation_0-logloss:0.49078
# [72]	validation_0-logloss:0.49037
# [73]	validation_0-logloss:0.48994
# [74]	validation_0-logloss:0.48954
# [75]	validation_0-logloss:0.48918
# [76]	validation_0-logloss:0.48882
# [77]	validation_0-logloss:0.48841
# [78]	validation_0-logloss:0.48805
# [79]	validation_0-logloss:0.48767
# [80]	validation_0-logloss:0.48710
# [81]	validation_0-logloss:0.48676
# [82]	validation_0-logloss:0.48644
# [83]	validation_0-logloss:0.48610
# [84]	validation_0-logloss:0.48566
# [85]	validation_0-logloss:0.48521
# [86]	validation_0-logloss:0.48487
# [87]	validation_0-logloss:0.48458
# [88]	validation_0-logloss:0.48420
# [89]	validation_0-logloss:0.48390
# [90]	validation_0-logloss:0.48359
# [91]	validation_0-logloss:0.48329
# [92]	validation_0-logloss:0.48297
# [93]	validation_0-logloss:0.48270
# [94]	validation_0-logloss:0.48239
# [95]	validation_0-logloss:0.48208
# [96]	validation_0-logloss:0.48175
# [97]	validation_0-logloss:0.48148
# [98]	validation_0-logloss:0.48120
# [99]	validation_0-logloss:0.48091
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=2,
#               enable_categorical=False, eta=0.9, eval_metric=None,
#               feature_types=None, gamma=4, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
test_score = model2.score(X_test, Y_test)

# %%
print(test_score)
# Out:
# 0.760096875
